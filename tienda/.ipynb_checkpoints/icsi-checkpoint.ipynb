# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('..\\data\\datos_ventas_icsi.csv')
df
# Out:
#         folio    caja usuario  dia       fecha dia_semana  cantidad  \
# 0           1  Caja 1   admin    0  2024-02-21  Wednesday      1.00
# 1           1  Caja 1   admin    0  2024-02-21  Wednesday      1.00
# 2           2  Caja 1   admin    0  2024-02-21  Wednesday      1.00
# 3           3  Caja 1   admin    0  2024-02-21  Wednesday      1.00
# 4           4  Caja 1   admin    0  2024-02-21  Wednesday      1.00
# ...       ...     ...     ...  ...         ...        ...       ...
# 108481  72844  Caja 1  SUSANA  203  2025-07-23  Wednesday      1.00
# 108482  72844  Caja 1  SUSANA  203  2025-07-23  Wednesday      0.14
# 108483  72845  Caja 1  SUSANA  203  2025-07-23  Wednesday      1.00
# 108484  72846  Caja 1  SUSANA  203  2025-07-23  Wednesday      2.00
# 108485  72847  Caja 1  SUSANA  203  2025-07-23  Wednesday      1.00
#
#                          producto  importe   valor  utilidad
# 0       Ariel Oxianillos De 500gm     28.0   25.93      2.07
# 1                     Axion 720gr     29.0   23.97      5.03
# 2                     Whiskas 1kg     53.0   43.79      9.21
# 3           Yomi Lala Fresa 190ml     11.0    6.50      4.50
# 4                 Trikitrakes 85g     18.0   14.28      3.72
# ...                           ...      ...     ...       ...
# 108481        Sardina Calmex 425g     42.0    1.46     40.54
# 108482               Queso Fresco     15.0   11.89      3.11
# 108483     Lala deslactosada 1lit     27.0   22.69      4.31
# 108484       HUEVO CRIO CONO 30PZ    172.0  161.46     10.54
# 108485           Vick Vaporub 12g     29.0   22.71      6.29
#
# [108486 rows x 11 columns]

# %% [markdown]
# ## Tickets

# %% [markdown]
# ¿Qué producto es el más vendido?

# %%
cantidad_productos = df.groupby('producto')[['cantidad']].sum()
cantidad_productos.sort_values('cantidad', ascending=False)
# Out:
#                                        cantidad
# producto
# MASTER XTREME MAYOREO RECARGA         805958.00
# MASTERXTREME MAYOREO RECARGA          703226.50
# MASTER TMAC MAYOREO RECARGA           314309.00
# RECARGAS XTREME (MULTICEL-MINISUPER)  297311.62
# MASTER SERVICIOS XTREME               182769.00
# ...                                         ...
# Harina Mayran Agranel 1K                   0.50
# Salchicha Tipo Hot Dog Agranel             0.50
# Chileancho x kg venta agranel              0.37
# Bolsa Natural 10x20 Salsa                  0.30
# Bolsa Natural 30x40 Para 3kg               0.25
#
# [2319 rows x 1 columns]

# %% [markdown]
# ¿Cuánto es el ticket promedio?

# %%
tickets = df.groupby('folio')[['importe']].sum()
tickets.median()
# Out:
# importe    33.0
# dtype: float64

# %% [markdown]
# Muestra una distribución

# %%
edges = [i for i in np.arange(-0.5, 101, 10)] + [i for i in np.arange(99.5, 501, 50)] +\
        [i for i in np.arange(499.5, 2001, 500)]
edge

# %%
plt.hist(tickets, bins)
plt.show()

# %% [markdown]
# ## ¿Qué caja vende más?
